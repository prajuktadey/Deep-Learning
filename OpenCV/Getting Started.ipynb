# %%
import numpy as np
import cv2 
from matplotlib import pyplot as plt

# %%
#loading the image
img = cv2.imread('sudoku.jpg')

# %%
#displaying the image
plt.imshow(img)

# %%
cv2.imwrite('output.jpg', img)
# Out:
# True

# %%
#size of first image
import os
os.stat('sudoku.jpg').st_size
# Out:
# 2161768

# %%
#size of the copied image
import os
os.stat('output.jpg').st_size
# Out:
# 1890362
