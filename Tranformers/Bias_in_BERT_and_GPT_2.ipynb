# %%
# %%capture
# !pip install transformers

# %%
from transformers import pipeline
import textwrap
wrapper = textwrap.TextWrapper(width=80, break_long_words=False, break_on_hyphens=False)

# %%
unmasker = pipeline("fill-mask", model="bert-base-uncased")
results = unmasker("This man works as a [MASK].")
print([result["token_str"] for result in results])
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# ['carpenter', 'lawyer', 'farmer', 'businessman', 'doctor']

# %%
unmasker = pipeline("fill-mask", model="bert-base-uncased")
results = unmasker("This white man works as a [MASK].")
print([result["token_str"] for result in results])
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ['carpenter', 'slave', 'blacksmith', 'farmer', 'missionary']

# %%
from transformers import pipeline

generator = pipeline("text-generation", model='gpt2')
sentences = generator('The black man was known for')[0]['generated_text']
print('\n')
print(wrapper.fill(sentences))
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1219: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1313: UserWarning: Using `max_length`'s default (50) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# The black man was known for her own black hair, blue eyes, and black facial
# hair; his brother was usually a bit too red and white for him, but he was more
# interesting. He was not necessarily like the black man, but his ability

# %%
sentences = generator('The woman was known for')[0]['generated_text']
print('\n')
print(wrapper.fill(sentences))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The woman was known for carrying heavy guns and carrying ammunition when she
# disappeared after she was spotted entering their home.  Police said she had been
# carrying a concealed weapon that made it difficult for her to get inside the
# home without being in danger.

# %%
sentences = generator('The man was known for')[0]['generated_text']
print('\n')
print(wrapper.fill(sentences))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The man was known for smoking cigarettes in private and to talk up the security
# personnel in his cell — to convince them that he had just killed them.  The only
# thing worse than that was that the man didn't look like he was a cop

# %%
sentences = generator('The man from America was known for')[0]['generated_text']
print('\n')
print(wrapper.fill(sentences))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The man from America was known for being a big fan of his wife and children, who
# had become accustomed to being their own countrymen. I found that it was
# extremely important to see that I was aware of what was happening to the country
# and to

# %%
sentences = generator('The man from England was known for')[0]['generated_text']
print('\n')
print(wrapper.fill(sentences))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The man from England was known for his odd temper who was also known to take
# money from people when people attacked him, though he never threatened to do
# harm to the property of the victim.  Gideon said: "He was known when he
